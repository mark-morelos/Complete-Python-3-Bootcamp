# %%
import requests

# %%
import bs4

# %%
# Grabbing page title

result = requests.get("http://www.example.com")

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %%
soup = bs4.BeautifulSoup(result.text,"lxml") # lxml for parsing

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Example Domain</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# <body>
# <div>
# ...

# %%
soup.select('title')
# Out:
# [<title>Example Domain</title>]

# %%
soup.select('p')
# Out:
# [<p>This domain is for use in illustrative examples in documents. You may use this
#      domain in literature without prior coordination or asking for permission.</p>,
#  <p><a href="https://www.iana.org/domains/example">More information...</a></p>]

# %%
soup.select('h1')
# Out:
# [<h1>Example Domain</h1>]

# %%
soup.select('title')[0].getText()
# Out:
# 'Example Domain'

# %%
soup.select('p')[0].getText()
# Out:
# 'This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.'

# %%
site_paragraphs = soup.select('p')

# %%
site_paragraphs[0]
# Out:
# <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>

# %%
type(site_paragraphs)
# Out:
# bs4.element.ResultSet

# %%
# Grabbing a class

# %% [markdown]
# <table>
#
# <thead >
# <tr>
# <th>
# <p>Syntax to pass to the .select() method</p>
# </th>
# <th>
# <p>Match Results</p>
# </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <p><code>soup.select('div')</code></p>
# </td>
# <td>
# <p>All elements with the <code>&lt;div&gt;</code> tag</p>
# </td>
# </tr>
# <tr>
# <td>
# <p><code>soup.select('#some_id')</code></p>
# </td>
# <td>
# <p>The HTML element containing the <code>id</code> attribute of <code>some_id</code></p>
# </td>
# </tr>
# <tr>
# <td>
# <p><code>soup.select('.notice')</code></p>
# </td>
# <td>
# <p>All the HTML elements with the CSS <code>class</code> named <code>notice</code></p>
# </td>
# </tr>
# <tr>
# <td>
# <p><code>soup.select('div span')</code></p>
# </td>
# <td>
# <p>Any elements named <code>&lt;span&gt;</code> that are within an element named <code>&lt;div&gt;</code></p>
# </td>
# </tr>
# <tr>
# <td>
# <p><code>soup.select('div &gt; span')</code></p>
# </td>
# <td>
# <p>Any elements named <code class="literal2">&lt;span&gt;</code> that are <span><em >directly</em></span> within an element named <code class="literal2">&lt;div&gt;</code>, with no other element in between</p>
# </td>
# </tr>
# <tr>
#
# </tr>
# </tbody>
# </table>

# %%
res = requests.get("https://en.wikipedia.org/wiki/Leni_Robredo")

# %%
soup = bs4.BeautifulSoup(res.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Leni Robredo - Wikipedia</title>
# ...

# %%
soup.select('.toctext')
# Out:
# [<span class="toctext">Early life and education</span>,
#  <span class="toctext">Political career</span>,
#  <span class="toctext">Congressional career</span>,
#  <span class="toctext">Legislative portfolio</span>,
#  <span class="toctext">Vice Presidency (2016-2022)</span>,
#  <span class="toctext">Policies</span>,
#  <span class="toctext">COVID-19 pandemic response</span>,
#  <span class="toctext">2019 Philippine Senate election</span>,
#  <span class="toctext">Fake news</span>,
#  <span class="toctext">Electoral protest</span>,
#  <span class="toctext">2022 presidential campaign</span>,
#  <span class="toctext">Post–vice presidency (2022–present)</span>,
#  <span class="toctext">Political positions</span>,
#  <span class="toctext">Domestic policies</span>,
#  <span class="toctext">Campaign against illegal drugs</span>,
#  <span class="toctext">Martial law</span>,
#  <span class="toctext">Political dynasties</span>,
#  <span class="toctext">Foreign policy</span>,
# ...

# %%
type(soup.select('.toctext')[0])
# Out:
# bs4.element.Tag

# %%
first_item = soup.select('.toctext')[0]

# %%
first_item.text
# Out:
# 'Early life and education'

# %%
for item in soup.select('.toctext'):
    print(item.text)
# Out:
# Early life and education
# Political career
# Congressional career
# Legislative portfolio
# Vice Presidency (2016-2022)
# Policies
# COVID-19 pandemic response
# 2019 Philippine Senate election
# Fake news
# Electoral protest
# 2022 presidential campaign
# Post–vice presidency (2022–present)
# Political positions
# Domestic policies
# Campaign against illegal drugs
# Martial law
# Political dynasties
# Foreign policy
# Personal life
# Honors and recognition
# Electoral history
# See also
# References
# External links

# %%
# Grabbing an Image

# %%
res = requests.get("https://en.wikipedia.org/wiki/Leni_Robredo")

# %%
soup = bs4.BeautifulSoup(res.text,"lxml")

# %%
soup.select('img')
# Out:
# [<img alt="Page semi-protected" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/>,
# ...

# %%
soup.select('img')[0]
# Out:
# <img alt="Page semi-protected" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/>

# %%
soup.select('.image') # look for class
# Out:
# [<a class="image" href="/wiki/File:VP_Leni_Robredo_official_portrait_(cropped).jpg"><img alt="VP Leni Robredo official portrait (cropped).jpg" data-file-height="943" data-file-width="629" decoding="async" height="330" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/83/VP_Leni_Robredo_official_portrait_%28cropped%29.jpg/220px-VP_Leni_Robredo_official_portrait_%28cropped%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/83/VP_Leni_Robredo_official_portrait_%28cropped%29.jpg/330px-VP_Leni_Robredo_official_portrait_%28cropped%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/83/VP_Leni_Robredo_official_portrait_%28cropped%29.jpg/440px-VP_Leni_Robredo_official_portrait_%28cropped%29.jpg 2x" width="220"/></a>,
# ...

# %%
soup.select('.image')[0]
# Out:
# <a class="image" href="/wiki/File:VP_Leni_Robredo_official_portrait_(cropped).jpg"><img alt="VP Leni Robredo official portrait (cropped).jpg" data-file-height="943" data-file-width="629" decoding="async" height="330" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/83/VP_Leni_Robredo_official_portrait_%28cropped%29.jpg/220px-VP_Leni_Robredo_official_portrait_%28cropped%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/83/VP_Leni_Robredo_official_portrait_%28cropped%29.jpg/330px-VP_Leni_Robredo_official_portrait_%28cropped%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/83/VP_Leni_Robredo_official_portrait_%28cropped%29.jpg/440px-VP_Leni_Robredo_official_portrait_%28cropped%29.jpg 2x" width="220"/></a>

# %%
leni_robredo = soup.select('.image')[0]

# %%
leni_robredo
# Out:
# <a class="image" href="/wiki/File:VP_Leni_Robredo_official_portrait_(cropped).jpg"><img alt="VP Leni Robredo official portrait (cropped).jpg" data-file-height="943" data-file-width="629" decoding="async" height="330" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/83/VP_Leni_Robredo_official_portrait_%28cropped%29.jpg/220px-VP_Leni_Robredo_official_portrait_%28cropped%29.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/83/VP_Leni_Robredo_official_portrait_%28cropped%29.jpg/330px-VP_Leni_Robredo_official_portrait_%28cropped%29.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/83/VP_Leni_Robredo_official_portrait_%28cropped%29.jpg/440px-VP_Leni_Robredo_official_portrait_%28cropped%29.jpg 2x" width="220"/></a>

# %%
leni_robredo['class']
# Out:
# ['image']

# %%
leni_robredo['src']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 leni_robredo['src']
#
# File /opt/anaconda3/lib/python3.9/site-packages/bs4/element.py:1519, in Tag.__getitem__(self, key)
#    1516 def __getitem__(self, key):
#    1517     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1518     and throws an exception if it's not there."""
# -> 1519     return self.attrs[key]
#
# KeyError: 'src'

# %% [markdown]
# <img src ="//upload.wikimedia.org/wikipedia/commons/thumb/8/83/VP_Leni_Robredo_official_portrait_%28cropped%29.jpg/220px-VP_Leni_Robredo_official_portrait_%28cropped%29.jpg">
